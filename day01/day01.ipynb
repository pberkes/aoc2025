# %%
# %matplotlib inline

import itertools
import re

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np


def map_array(map_txt):
    rows = map_txt.splitlines()
    map_ = np.array([list(r) for r in rows])
    return map_


def print_map(map_):
    for row in map_:
        print(''.join(row))

        
def out_of_bounds(pos, n, m):
    return (pos[0] < 0) | (pos[0] >= n) | (pos[1] < 0) | (pos[1] >= m)


directions = [(0, 1), (1, 0), (0, -1), (-1, 0)]

# %%
txt = """
L68
L30
R48
L5
R60
L55
L1
L99
R14
L82
""".strip()

# %%
with open('input.txt', 'r') as f:
    txt = f.read().strip()

# %% [markdown]
# # Part 1

# %%
size = 100
pos = 50
zeros = 0
for l in txt.splitlines():
    dir_ = l[0]
    steps = int(l[1:])
    if dir_ == 'L':
        pos -= steps
    else:
        pos += steps
    if pos % size == 0:
        zeros += 1
zeros
# Out:
# 997

# %% [markdown]
# # Part 2

# %%
txt = """
R40
R20
""".strip()

txt = """
L60
L110
L85
L95
""".strip()


txt = """
R55
R105
R90
""".strip()

# %%
size = 100
pos = 50
zeros = 0

for l in txt.splitlines():
    dir_ = l[0]
    steps = int(l[1:])
    prev_positive = pos > 0
    
    delta_zeros = steps // size
    steps = steps % size
    
    if dir_ == 'L':
        pos -= steps
    else:
        pos += steps
        
    delta_zeros += abs(pos) // size
    if prev_positive & (pos < 0):
        delta_zeros += 1
    elif pos == 0:
        delta_zeros += 1

    zeros += delta_zeros    
    pos = pos % size

zeros
# Out:
# 5978
