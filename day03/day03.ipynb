# %%
# %matplotlib inline

import itertools
import re

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np


def map_array(map_txt):
    rows = map_txt.splitlines()
    map_ = np.array([list(r) for r in rows])
    return map_


def print_map(map_):
    for row in map_:
        print(''.join(row))

        
def out_of_bounds(pos, n, m):
    return (pos[0] < 0) | (pos[0] >= n) | (pos[1] < 0) | (pos[1] >= m)


directions = [(0, 1), (1, 0), (0, -1), (-1, 0)]

# %%
txt = """
987654321111111
811111111111119
234234234234278
818181911112111
""".strip()

# %%
with open('input.txt', 'r') as f:
    txt = f.read().strip()

# %% [markdown]
# # Part 1

# %%
def max_joltage(bank):
    len_bank = len(bank)
    max_joltage = 0
    for i in range(len_bank):
        for j in range(i + 1, len_bank):
            joltage = int(bank[i] + bank[j])
            max_joltage = max(max_joltage, joltage)
    return max_joltage


test_cases = [
    ('811111111111119', 89),
    ('234234234234278', 78)
]
for bank, expected in test_cases:
    result = max_joltage(bank)
    print(result, expected, result == expected)
# Out:
# 89 89 True
# 78 78 True

# %%
banks = txt.splitlines()

# %%
tot = 0
for bank in banks:
    tot += max_joltage(bank)
    
tot
# Out:
# 17074

# %% [markdown]
# # Part 2

# %%
from itertools import combinations


def max_joltage(bank):
    max_digits = ''
    for i in range(12):
        if len(bank) <= (12 - i):
            # we collected all the max digits, we need to return the rest of the number
            max_digits = max_digits + bank
            break

        max_digit = max(bank[:len(bank) - 12 + i + 1])
        idx_max_digit = bank.find(max_digit)
        max_digits = max_digits + max_digit
        bank = bank[idx_max_digit+1:]
    joltage = int(''.join(max_digits))
    return joltage


test_cases = [
    ('811111111111119', 811111111119),
    ('234234234234278', 434234234278)
]
for bank, expected in test_cases:
    result = max_joltage(bank)
    print(result, expected, result == expected)
# Out:
# 811111111119 811111111119 True
# 434234234278 434234234278 True

# %%
banks = txt.splitlines()

tot = 0
for bank in banks:
    tot += max_joltage(bank)
    
tot
# Out:
# 169512729575727
